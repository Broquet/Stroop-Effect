# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

titanic_all = pd.read_csv('Desktop/titanic-data.csv')
titanic_all
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# The are 891 lines of dta. age variable and cabin value have missing values. We can clean the data to remove lines without value.
#
# Were women and children really saved before men?
# Is the chance of survival higher if passengers were coming from a higher class?

# %%
import pandas as pd
titanic_all = pd.read_csv('Desktop/titanic-data.csv')
print titanic_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None

# %%
import pandas as pd
titanic_all = pd.read_csv('Desktop/titanic-data.csv')
print titanic_all.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import pandas as pd
titanic_all = pd.read_csv('Desktop/titanic-data.csv')
titanic_all.dropna(subset=['Age'], how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...

# %%
Women = titanic_all[titanic_all.Sex == 'female']
Women = titanic_all[titanic_all.Age >= 18]
Men = titanic_all[titanic_all.Sex == 'male']
Men = titanic_all[titanic_all.Age >= 18]
Children = Men = titanic_all[titanic_all.Age <= 18]

sns.set(style='whitegrid')
# %matplotlib inline


Histogram1 = sns.factorplot('Sex', data=titanic_all, kind='count')
Histogram1.set_ylabels("Passengers")

# %% [markdown]
# Find the average age of women

# %%
import pandas as pd

titanic_all = pd.read_csv('Desktop/titanic-data.csv')
mytest=titanic_all.dropna(subset=['Age'], how='any')
Allwomen = mytest[mytest.Sex == 'female']

print Allwomen.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   261.000000  261.000000  261.000000  261.000000  261.000000
# mean    440.199234    0.754789    2.065134   27.915709    0.639847
# std     260.607601    0.431039    0.845560   14.110146    0.928493
# min       2.000000    0.000000    1.000000    0.750000    0.000000
# 25%     234.000000    1.000000    1.000000   18.000000    0.000000
# 50%     428.000000    1.000000    2.000000   27.000000    0.000000
# 75%     652.000000    1.000000    3.000000   37.000000    1.000000
# max     888.000000    1.000000    3.000000   63.000000    5.000000
#
#             Parch        Fare
# count  261.000000  261.000000
# mean     0.708812   47.582759
# std      1.066752   61.346854
# min      0.000000    6.750000
# 25%      0.000000   13.000000
# 50%      0.000000   26.000000
# 75%      1.000000   57.979200
# max      6.000000  512.329200

# %%
import pandas as pd

titanic_all = pd.read_csv('Desktop/titanic-data.csv')
mytest=titanic_all.dropna(subset=['Age'], how='any')
Allwomen = mytest[mytest.Survived == True]

print Allwomen.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   290.000000     290.0  290.000000  290.000000  290.000000  290.000000
# mean    457.768966       1.0    1.872414   28.343690    0.493103    0.527586
# std     250.845515       0.0    0.836617   14.950952    0.731132    0.807147
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     260.500000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     452.000000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     669.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  290.000000
# mean    51.843205
# std     70.458776
# min      0.000000
# 25%     13.000000
# 50%     26.250000
# 75%     66.200000
# max    512.329200

# %%
def Adultchild(passenger):
    age, sex = passenger
    
    if age < 21:
        return 'child'
    else:
        return sex
titanic_all['Adultchild'] = titanic_all[['Age', 'Sex']].apply(Adultchild, axis=1)

titanic_all.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 861      male
# 862    female
# 863    female
# 864      male
# 865    female
# 866    female
# 867      male
# 868      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 878      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# ...

# %%
titanic_all['Age'].hist(bins=10)
plt.title("Age structure of passengers")

# %%
myPlot = sns.factorplot('Pclass'), order=[1,2,3], data=titanic_all, hue= 'Adultchild'
myPlot.set_ylabels("Passengers")
plt.title("Persons having survived, males, females and children per passengers")
# Out:
#   File "<ipython-input-29-30548461b8af>", line 1
#     myPlot = sns.factorplot('Pclass'), order=[1,2,3], data=titanic_all, hue= 'Adultchild'
# SyntaxError: can't assign to function call

# %%
all_with_age = survival_subset[pd.notnull(survival_subset["Age"])] # dropping all rows with no age data
children = all_with_age[all_with_age["Age"] < 16] # subsetting by <16 years old

def generate_gender_data(sex="female"):
    subset = all_with_age[all_with_age["Sex"] == sex]
    return subset[~subset.isin(children)].dropna() # get adults by dropping all rows that are in children's table

women = generate_gender_data()
men = generate_gender_data(sex="male")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-dd47cce536f4> in <module>()
# ----> 1 all_with_age = survival_subset[pd.notnull(survival_subset["Age"])] # dropping all rows with no age data
#       2 children = all_with_age[all_with_age["Age"] < 16] # subsetting by <16 years old
#       3
#       4 def generate_gender_data(sex="female"):
#       5     subset = all_with_age[all_with_age["Sex"] == sex]
#
# NameError: name 'survival_subset' is not defined

# %%
Woman = titanic_all[titanic_all.Sex == 'female']

pd.DataFrame({"Women": {0: len(women)}, "Children": {0: len(children)}, "Men": {0: len(men)}})
